# %%
import pickle
import pandas as pd

# %%
dataset = pickle.load(open('processed_dataset.pkl','rb'))

# %%
dataset.to_csv('data_csv_form.csv')

# %%
dataset
# Out:
#             team_1       team_2          city  result
# 0          England    Australia   Southampton       1
# 1      New Zealand    Australia      Auckland       0
# 2     South Africa  New Zealand  Johannesburg       0
# 3          England     Pakistan       Bristol       0
# 4          England    Sri Lanka   Southampton       0
# ...            ...          ...           ...     ...
# 2056   New Zealand  West Indies      Kingston       1
# 2057   New Zealand  West Indies      Kingston       0
# 2212      Zimbabwe   Bangladesh        Harare       1
# 2213      Zimbabwe   Bangladesh        Harare       0
# 2214      Zimbabwe   Bangladesh        Harare       1
#
# [808 rows x 4 columns]

# %%
dataset['city'].value_counts()
# Out:
# Colombo         44
# Mirpur          29
# Johannesburg    29
# Dhaka           24
# Auckland        24
#                 ..
# Dharmasala       1
# Kimberley        1
# Taunton          1
# Kanpur           1
# Hyderabad        1
# Name: city, Length: 103, dtype: int64

# %%
eligiblie_citys = ['Colombo','Mirpur','Johannesburg',         
'Dhaka',                 
'Auckland',              
'Abu Dhabi',             
'Cape Town',             
'London',                
'Barbados',              
'Wellington',            
'Durban',                
'Nottingham',            
'Lauderhill',            
'Lahore',                
'St Lucia',             
'Hamilton',              
'Harare',                
'Centurion',             
'Southampton',           
'Kolkata',               
'Belfast',               
'Manchester',            
'Dubai',                 
'Sydney',                 
'Mount Maunganui',        
'Cardiff',]

# %%
dataset['team_1'].value_counts()
# Out:
# New Zealand     100
# India            97
# Australia        89
# South Africa     86
# England          82
# Bangladesh       67
# West Indies      65
# Sri Lanka        65
# Pakistan         58
# Afghanistan      49
# Zimbabwe         38
# Ireland          12
# Name: team_1, dtype: int64

# %%
count = 0
count1 = 0
count3 = 0
for i in dataset['city']:
    print(i in eligiblie_citys)
    count = count + 1
    if (i in eligiblie_citys):
        count1 = count1 + 1
    else:
        dataset['city'] = dataset['city'].replace(i,"NULL")
# Out:
# True
# True
# True
# False
# True
# False
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# False
# True
# False
# True
# True
# True
# False
# False
# False
# True
# False
# True
# True
# True
# True
# False
# False
# False
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# False
# True
# True
# True
# False
# True
# True
# True
# False
# False
# True
# True
# True
# False
# False
# False
# False
# False
# True
# True
# False
# True
# True
# False
# False
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# ...

# %%
dataset['city'].value_counts()
# Out:
# NULL               383
# Colombo             44
# Johannesburg        29
# Mirpur              29
# Dhaka               24
# Auckland            24
# Abu Dhabi           23
# Cape Town           21
# London              20
# Barbados            17
# Wellington          15
# Durban              13
# Nottingham          13
# Lahore              12
# Lauderhill          12
# Centurion           12
# St Lucia            12
# Hamilton            12
# Harare              12
# Belfast             11
# Southampton         11
# Kolkata             11
# Manchester          11
# Dubai               10
# Sydney               9
# Mount Maunganui      9
# Cardiff              9
# Name: city, dtype: int64

# %%
pickle.dump(dataset,open('final_dataset_before_spliting.pkl','wb'))

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['team_1','team_2','city'])
]
,remainder='passthrough')

# %%
X = dataset.iloc[:,:-1]
y = dataset.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['team_1', 'team_2',
#                                                    'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.5925925925925926

# %%
from sklearn.svm import SVC
pipe1 = Pipeline(steps=[
    ('step1',trf),
    ('step3',SVC(kernel = 'linear', random_state = 0))
])
pipe1.fit(X_train,y_train)
y_pred = pipe1.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.6172839506172839

# %%
from sklearn.naive_bayes import GaussianNB
#classifier = 
pipe2 = Pipeline(steps=[
    ('step1',trf),
    ('step2',GaussianNB())
])
pipe2.fit(X_train,y_train)
y_pred = pipe2.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.5617283950617284

# %%
from sklearn.tree import DecisionTreeClassifier

pipe3 = Pipeline(steps=[
    ('step1',trf),
    ('step2',DecisionTreeClassifier(criterion = 'entropy', random_state = 0))
])
pipe3.fit(X_train,y_train)
y_pred = pipe3.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.5432098765432098

# %%
from sklearn.ensemble import RandomForestClassifier
#classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
pipe4 = Pipeline(steps=[
    ('step1',trf),
    ('step2',RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0))
])
pipe4.fit(X_train,y_train)
y_pred = pipe4.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.5925925925925926

# %%
pickle.dump(pipe1,open('Match_winning_propablity_calculator_using_svm_model.pkl','wb'))

# %%
input_df = pd.DataFrame({'team_1':'India','team_2':'England','city':'Sydney'}, index=[0])

# %%
pipe = pickle.load(open('Match_winning_propablity_calculator_using_svm_model.pkl','rb'))

# %%
pipe.predict(input_df)
# Out:
# array([1])
